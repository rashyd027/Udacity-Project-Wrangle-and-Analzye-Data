# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %% [markdown]
# ##### Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
import os
import json
import tweepy
import re
import warnings
warnings.filterwarnings("ignore")

# %%
twitter_archive = pd.read_csv('C:/Users/Rasheed Lawal/Downloads/twitter-archive-enhanced.csv', sep=',')

# %%
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
# Creating a directory if non-existence
folder_name = 'image_predictions'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
# Storing the url in a variable
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# Opening the file
with open(os.path.join(folder_name, url.split('/')[-1]) , mode='wb') as file:
    file.write(response.content)

# %%
# Reading the file into a dataframe
image_predictions = pd.read_csv(url, sep='\t')

# %%
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
# Importing packages
from tweepy import OAuthHandler
from timeit import default_timer as timer

# %%
consumer_key = '---------------'
consumer_secret = '------------------'
access_token = '-------------------'
access_secret = '-------------------'

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Tweet id to gather data via twitter API
tweet_ids = df1.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
tweet_ids
# Out:
# array([892420643555336193, 892177421306343426, 891815181378084864, ...,
#        666033412701032449, 666029285002620928, 666020888022790149],
#       dtype=int64)

# %%
# Getting the status of a tweet id
status = api.get_status(892420643555336193, tweet_mode='extended')
status
# Out:
# Status(_api=<tweepy.api.API object at 0x00000208CD313D90>, _json={'created_at': 'Tue Aug 01 16:23:56 +0000 2017', 'id': 892420643555336193, 'id_str': '892420643555336193', 'full_text': "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU", 'truncated': False, 'display_text_range': [0, 85], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 892420639486877696, 'id_str': '892420639486877696', 'indices': [86, 109], 'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg', 'url': 'https://t.co/MgUWQ76dJU', 'display_url': 'pic.twitter.com/MgUWQ76dJU', 'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 540, 'h': 528, 'resize': 'fit'}, 'small': {'w': 540, 'h': 528, 'resize': 'fit'}, 'large': {'w'
# ...

# %%
import time
from tweepy import TweepyException
# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0

# creating an error dictionary to catch errors that might occur
error_dict = {}
start_time = time.time()

# Saving each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as file:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            # Getting the status id of each tweet id
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            # Converting each tweet status to a JSON object/string and saving to a file
            json.dump(tweet._json, file)
            file.write('\n')
        # Catching errors that occured 
        except tweepy.TweepyException as error:
            print("Error")
            # Appending errors to error_dict
            error_dict[tweet_id] = error
            pass
end_time = time.time()
print(end_time - start_time)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Error
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
print(error_dict)
# Out:
# {888202515573088257: NotFound('404 Not Found\n144 - No status found with that ID.'), 873697596434513921: NotFound('404 Not Found\n144 - No status found with that ID.'), 872668790621863937: NotFound('404 Not Found\n144 - No status found with that ID.'), 872261713294495745: NotFound('404 Not Found\n144 - No status found with that ID.'), 869988702071779329: NotFound('404 Not Found\n144 - No status found with that ID.'), 866816280283807744: NotFound('404 Not Found\n144 - No status found with that ID.'), 861769973181624320: NotFound('404 Not Found\n144 - No status found with that ID.'), 856602993587888130: NotFound('404 Not Found\n144 - No status found with that ID.'), 856330835276025856: NotFound('404 Not Found\n144 - No status found with that ID.'), 851953902622658560: NotFound('404 Not Found\n144 - No status found with that ID.'), 851861385021730816: NotFound('404 Not Found\n144 - No status found with that ID.'), 845459076796616705: NotFound('404 Not Found\n144 - No status found with t
# ...

# %%
# Creating an empty list
tweets_data_list = []
# Opening and Reading text file
with open('tweet_json.txt', 'r') as json_file:
    for line in json_file.readlines():
        tweet_line = json.loads(line)
        # Getting the requred columns
        tweet_id = tweet_line['id']
        retweet_count = tweet_line['retweet_count']
        favorite_count = tweet_line['favorite_count']
        
         # Appending each to the list
        df3_list.append({
                "tweet_id" : tweet_id,
                "retweet_count" : retweet_count,
                "favorite_count" : favorite_count})

# %%
# Converting to pandas dataframe
tweets_data = pd.DataFrame(df3_list, columns=["tweet_id",'retweet_count', 'favorite_count'])

# %%
tweets_data.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           6978           33722
# 1  892177421306343426           5279           29250
# 2  891815181378084864           3465           21978
# 3  891689557279858688           7198           36817
# 4  891327558926688256           7722           35203

# %% [markdown]
# ## Assessing Twitter archive data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# *Column Headers Description:*
# (Some of these descriptions were gotten from twitter, while others were gotten from the Project Motivation)
# * tweet_id: unique id for each tweet by the twitter account @DogRates.
# * in_reply_to_status_id: this field will contain the integer representation of the original tweet's ID if the represented tweet is a reply.
# * in_reply_to_user_id: this field will contain the integer representation of the original tweet's author ID if the represented tweet is a reply. This will not necessarily always be the user directly mentioned in the tweet.
# * timestamp: the time the tweet was tweeted.
# * source: the source of the tweet.
# * text: the content of the tweet.
# * retweeted_status_id: this attribute contains a representation of the time the original tweet was retweeted.
# * retweeted_status_user_id: the id of the retweeted status user.
# * retweeted_status_timestamp: this attribute contains a representation of the time the original tweet was retweeted.
# * expanded_urls: the url of the tweet(can be used to access the tweet directly).
# * rating_numerator: numerator of the ratings for the dog.
# * rating_denominator: denominator of the ratings for the dog.
# * name: the name of the dog.
# * doggo: this is one of the dog stages.
# * floofer: this is one of the dog stages.
# * pupper: this is one of the dog stages.
# * puppo: this is one of the dog stages.

# %% [markdown]
# ### Visual Assessment

# %%
twitter_archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %% [markdown]
# ### Programmatic Assessment

# %%
# Displaying the first five rows of the data
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# Displaying the last five rows of the data
twitter_archive.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# Displaying random number of rows from the data
twitter_archive.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2162  669393256313184256                    NaN                  NaN
# 644   793180763617361921                    NaN                  NaN
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2189  668967877119254528           6.689207e+17         2.143566e+07
# 1874  675135153782571009                    NaN                  NaN
# 1622  684914660081053696                    NaN                  NaN
# 660   791312159183634433                    NaN                  NaN
# 2091  670783437142401025                    NaN                  NaN
# 972   750086836815486976                    NaN                  NaN
# 1698  681193455364796417                    NaN                  NaN
#
#                       timestamp  \
# 2162  2015-11-25 05:52:43 +0000
# 644   2016-10-31 20:00:05 +0000
# 2038  2015-12-01 04:44:10 +0000
# 2189  2015-11-24 01:42:25 +0000
# 1874  2015-12-11 02:08:58 +0000
# ...

# %%
# Getting the number of rows and columns in the data
twitter_archive.shape
# Out:
# (2356, 17)

# %% [markdown]
# The twitter archive data contains 2356 rows and 17 columns.

# %%
# Displaying a concise summary of the data
twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
# Displaying the data statistics
twitter_archive.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
# Checking for duplicates in the data
twitter_archive.duplicated().sum()
# Out:
# 0

# %%
# Checking for null values
twitter_archive.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
# Getting the count of unique values in rating_denominator column in descending order
twitter_archive.rating_denominator.value_counts().sort_index(ascending = False)
# Out:
# 170       1
# 150       1
# 130       1
# 120       1
# 110       1
# 90        1
# 80        2
# 70        1
# 50        3
# 40        1
# 20        2
# 16        1
# 15        1
# 11        3
# 10     2333
# 7         1
# 2         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
# displaying the rows where the rating_denominator is not equals to 10
twitter_archive.rating_denominator[twitter_archive.rating_denominator != 10]
# Out:
# 313       0
# 342      15
# 433      70
# 516       7
# 784      11
# 902     150
# 1068     11
# 1120    170
# 1165     20
# 1202     50
# 1228     90
# 1254     80
# 1274     50
# 1351     50
# 1433     40
# 1598     20
# 1634    130
# 1635    110
# 1662     11
# 1663     16
# 1779    120
# 1843     80
# 2335      2
# Name: rating_denominator, dtype: int64

# %%
# Getting the number of the rows where the rating denominator is not equals to 10
len(twitter_archive.rating_denominator[twitter_archive.rating_denominator != 10])
# Out:
# 23

# %% [markdown]
# There are 23 rows in the dataframe that the rating_denominator is not equals to 10, which portrays an inconsistent issue that need to be addressed.

# %%
# Displaying the count of unique values in rating_numerator column in ascending order
twitter_archive.rating_numerator.value_counts().sort_index(ascending = False)
# Out:
# 1776      1
# 960       1
# 666       1
# 420       2
# 204       1
# 182       1
# 165       1
# 144       1
# 143       1
# 121       1
# 99        1
# 88        1
# 84        1
# 80        1
# 75        2
# 60        1
# 50        1
# 45        1
# 44        1
# 27        1
# 26        1
# 24        1
# 20        1
# 17        1
# 15        2
# 14       54
# 13      351
# 12      558
# 11      464
# 10      461
# 9       158
# 8       102
# 7        55
# 6        32
# 5        37
# 4        17
# 3        19
# 2         9
# 1         9
# 0         2
# Name: rating_numerator, dtype: int64

# %% [markdown]
# As observed, there are rows where the rating_numerators are greater than 10. This does not need to be addressed as it is part of the unique rating system of @DogRates.

# %%
# Displaying count of unique values in the name column
twitter_archive.name.value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Cooper         11
# Lucy           11
#              ...
# Dex             1
# Ace             1
# Tayzie          1
# Grizzie         1
# Christoper      1
# Name: name, Length: 957, dtype: int64

# %% [markdown]
# It is noticed that most of the dog names that are not real names are starting with lowercase

# %%
# Getting the list of names starting with lowercase using Regex
lower_names = twitter_archive.name.str.contains('^[a-z]', regex = True)
twitter_archive[lower_names].name.value_counts().sort_index()
# Out:
# a               55
# actually         2
# all              1
# an               7
# by               1
# getting          2
# his              1
# incredibly       1
# infuriating      1
# just             4
# life             1
# light            1
# mad              2
# my               1
# not              2
# officially       1
# old              1
# one              4
# quite            4
# space            1
# such             1
# the              8
# this             1
# unacceptable     1
# very             5
# Name: name, dtype: int64

# %%
# Getting the number of names with lowercase
len(twitter_archive[lower_names].name)
# Out:
# 109

# %% [markdown]
# It is confirmed that all strings starting with lowercase are not dog names.

# %%
# Displaying the count of unique values in the source column of the dataframe
twitter_archive.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
# Displaying the content of the text in the first row
twitter_archive.text[0]
# Out:
# "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU"

# %%
# Displaying column names for possible merging
twitter_archive.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %% [markdown]
# ## Assessing Image predictions data

# %% [markdown]
# *Column Headers Description:* (columns description was gotten from Project Motivation)
# * tweet_id: unique id for each tweet by the twitter account.
# * jpg_url: url for the dog image.
# * img_num: image number ranging from 1 to 4.
# * p1: the algorithm's #1 prediction for the image in the tweet.
# * p1_conf: how confident the algorithm is in its #1 prediction.
# * p1_dog: describes whether or not the #1 prediction is a breed of dog.
# * p2: the algorithm's #2 prediction for the image in the tweet.
# * p2_conf: describes how confident the algorithm is in its #2 prediction.
# * p2_dog: describes whether or not the #2 prediction is a breed of dog.
# * p3: the algorithm's #3 prediction for the image in the tweet.
# * p3_conf: describes how confident the algorithm is in its #3 prediction.
# * p3_dog: describes whether or not the #3 prediction is a breed of dog.

# %% [markdown]
# ### Visual Assessment

# %%
image_predictions
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %% [markdown]
# ### Programmatic Assessment

# %%
# Displaying the first five rows
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
# Displaying the last five rows
image_predictions.tail()
# Out:
#                 tweet_id                                          jpg_url  \
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 2070        2       basset  0.555712    True    English_springer  0.225770
# 2071        1  paper_towel  0.170278   False  Labrador_retriever  0.168086
# 2072        1    Chihuahua  0.716012    True            malamute  0.078253
# 2073        1    Chihuahua  0.323581    True            Pekinese  0.090647
# 2074        1       orange  0.097049   False               bagel  0.085851
#
#       p2_dog                           p3   p3_conf  p3_dog
# ...

# %%
# Displaying random number of rows
image_predictions.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 136   668507509523615744  https://pbs.twimg.com/media/CUcECBYWcAAzFRg.jpg
# 251   670704688707301377  https://pbs.twimg.com/media/CU7SW39WwAAL8Rw.jpg
# 181   669328503091937280  https://pbs.twimg.com/media/CUnuuLEWEAAlKjN.jpg
# 556   677673981332312066  https://pbs.twimg.com/media/CWeU5LBWEAA8F0J.jpg
# 988   707776935007539200  https://pbs.twimg.com/media/CdKHWimWoAABs08.jpg
# 1335  758041019896193024  https://pbs.twimg.com/media/CoUaSKEXYAAYsAl.jpg
# 727   686377065986265092  https://pbs.twimg.com/media/CYaAS2kUoAINkye.jpg
# 1474  780459368902959104  https://pbs.twimg.com/media/CtS_p9kXEAE2nh8.jpg
# 1068  715928423106027520  https://pbs.twimg.com/media/Ce99GhLW8AAHG38.jpg
# 108   667878741721415682  https://pbs.twimg.com/media/CUTILFiWcAE8Rle.jpg
#
#       img_num                  p1   p1_conf  p1_dog                  p2  \
# 136         1             basenji  0.055379    True   Shetland_sheepdog
# ...

# %%
# Displaying the number of rows and columns
image_predictions.shape
# Out:
# (2075, 12)

# %% [markdown]
# The image predictions dataframe contains 2075 rows and 12 columns

# %%
# Displaying a concise summary of the data
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
# Displaying data statistics for numerical variables
image_predictions.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
# Checking for duplicates
image_predictions.duplicated().sum()
# Out:
# 0

# %%
# Checking for null values or missing data
image_predictions.isnull().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
# Getting counts of unique values of p1_dog column
image_predictions.p1_dog.value_counts()
# Out:
# True     1532
# False     543
# Name: p1_dog, dtype: int64

# %%
# Getting counts of unique values for p1 column
image_predictions.p1.value_counts()
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# pillow                  1
# carousel                1
# bald_eagle              1
# lorikeet                1
# orange                  1
# Name: p1, Length: 378, dtype: int64

# %%
# Getting counts of unique values for p1_conf column
image_predictions.p1_conf.value_counts()
# Out:
# 0.721188    2
# 0.676439    2
# 0.505370    2
# 0.777468    2
# 0.254856    2
#            ..
# 0.141432    1
# 0.722218    1
# 0.278600    1
# 0.375610    1
# 0.097049    1
# Name: p1_conf, Length: 2006, dtype: int64

# %%
# Displaying column names for possible merging
image_predictions.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %% [markdown]
# ## Assessing Tweets data

# %% [markdown]
# *Column Headers Description:*
# * tweet_id: unique id for each tweet by the twitter account @DogRates.
# * retweet_count: the number of times the tweet has been retweeted.
# * favorite_count: the number of times the tweet has been liked.

# %% [markdown]
# ### Visual Assessment

# %%
tweets_data
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           6978           33722
# 1     892177421306343426           5279           29250
# 2     891815181378084864           3465           21978
# 3     891689557279858688           7198           36817
# 4     891327558926688256           7722           35203
# ...                  ...            ...             ...
# 4649  666049248165822465             36              88
# 4650  666044226329800704            115             246
# 4651  666033412701032449             36             100
# 4652  666029285002620928             39             112
# 4653  666020888022790149            420            2284
#
# [4654 rows x 3 columns]

# %% [markdown]
# ### Programmatic Assessment

# %%
# Displaying the first five rows
tweets_data.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           6978           33722
# 1  892177421306343426           5279           29250
# 2  891815181378084864           3465           21978
# 3  891689557279858688           7198           36817
# 4  891327558926688256           7722           35203

# %%
# Displaying the last five rows
tweets_data.tail()
# Out:
#                 tweet_id  retweet_count  favorite_count
# 4649  666049248165822465             36              88
# 4650  666044226329800704            115             246
# 4651  666033412701032449             36             100
# 4652  666029285002620928             39             112
# 4653  666020888022790149            420            2284

# %%
# Checking random rows
tweets_data.sample(10)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 3217  756939218950160384           1831            6196
# 2633  834167344700198914           3359           14812
# 2800  813800681631023104           1640            7868
# 913   752932432744185856           6282           11731
# 2939  793962221541933056           4557           15876
# 2503  856526610513747968           1651           10798
# 2804  813172488309972993           1803            8785
# 2614  836397794269200385          25037               0
# 294   835309094223372289          19126               0
# 1163  717841801130979328            542            2269

# %%
# Displaying the number of rows and columns
tweets_data.shape
# Out:
# (4654, 3)

# %% [markdown]
# The Tweets data contains 2327 rows and 3 columns

# %%
# Displaying a concise summary of the data
tweets_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4654 entries, 0 to 4653
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        4654 non-null   int64
#  1   retweet_count   4654 non-null   int64
#  2   favorite_count  4654 non-null   int64
# dtypes: int64(3)
# memory usage: 109.2 KB

# %%
# Checking for duplicated rows
tweets_data.duplicated().sum()
# Out:
# 2327

# %%
# Checking for missing data or null values
tweets_data.isnull().sum()
# Out:
# tweet_id          0
# retweet_count     0
# favorite_count    0
# dtype: int64

# %%
# Checking column names for possible merging
tweets_data.columns
# Out:
# Index(['tweet_id', 'retweet_count', 'favorite_count'], dtype='object')

# %% [markdown]
# ### Quality issues
# 1. Missing values in in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls columns in the twitter archive dataframe.
#
# 2. Irrelevant data (i.e. img_num column) in the image predictions dataframe that needs to be dropped.
#
# 3. The source column in the twitter archive data should be text only and not a combination of url and text.
#
# 4. Incorrect dog names in the name column of the twitter archive data(quite, none, a, an etc) should be dropped.
#
# 5. The rating denominator in the twitter archive data is not 10 in some rows.
#
# 6. Incorrect datatypes of timestamp and retweeted_status_timestamp in the twitter archive data.
#
# 7. retweeted_status_id column is not null and needs to be dropped as only tweets is needed.
#
# 8. tweet_id as an integer instead of string.
# 9. Redundant text column.

# %% [markdown]
# ### Tidiness issues
# 1. The dog stages in the twitter archive data should be in a single column and not separated into four columns.
#
# 2. The three dataframes needs to be merged as one master dataframe for better analysis and visualization.

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
twitter_archive_clean = twitter_archive.copy()
image_predictions_clean = image_predictions.copy()
tweets_data_clean = tweets_data.copy()

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define:
# Drop columns in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, and expanded_urls as they contain missing values and will not be needed for the analysis.

# %% [markdown]
# #### Code

# %%
twitter_archive_clean.drop(columns=['in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp', 'expanded_urls'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.shape
# Out:
# (2356, 11)

# %%
twitter_archive_clean.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   object
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   rating_numerator    2356 non-null   int64
#  5   rating_denominator  2356 non-null   int64
#  6   name                2356 non-null   object
#  7   doggo               2356 non-null   object
#  8   floofer             2356 non-null   object
#  9   pupper              2356 non-null   object
#  10  puppo               2356 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 202.6+ KB

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define
# Drop column image number(img_num) in the image predictions dataframe as it will not be used for the analysis.

# %% [markdown]
# #### Code

# %%
image_predictions_clean.drop('img_num', axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
image_predictions_clean.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
image_predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   p1        2075 non-null   object
#  3   p1_conf   2075 non-null   float64
#  4   p1_dog    2075 non-null   bool
#  5   p2        2075 non-null   object
#  6   p2_conf   2075 non-null   float64
#  7   p2_dog    2075 non-null   bool
#  8   p3        2075 non-null   object
#  9   p3_conf   2075 non-null   float64
#  10  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(4)
# memory usage: 135.9+ KB

# %% [markdown]
# ### Issue #3:

# %% [markdown]
# #### Define:
# Extract the source text from the source column in the twitter archive clean data

# %% [markdown]
# #### Code

# %%
# Displaying the unique values of the source column
twitter_archive_clean.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
# Replacing the source with only the text
twitter_archive_clean.source.replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'Twitter for iPhone', inplace=True)
twitter_archive_clean.source.replace('<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>', 'Vine - Make a Scene', inplace=True)
twitter_archive_clean.source.replace('<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'Twitter Web Client', inplace=True)
twitter_archive_clean.source.replace('<a href="http://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'TweetDeck', inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.source.value_counts()
# Out:
# Twitter for iPhone                                                                     2221
# Vine - Make a Scene                                                                      91
# Twitter Web Client                                                                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
twitter_archive_clean.head(3)
# Out:
#              tweet_id                  timestamp              source  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000  Twitter for iPhone
# 1  892177421306343426  2017-08-01 00:17:27 +0000  Twitter for iPhone
# 2  891815181378084864  2017-07-31 00:18:03 +0000  Twitter for iPhone
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
# 1  This is Tilly. She's just checking pup on you....                13
# 2  This is Archie. He is a rare Norwegian Pouncin...                12
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None
# 1                  10    Tilly  None    None   None  None
# 2                  10   Archie  None    None   None  None

# %% [markdown]
# ### Issue #4:

# %% [markdown]
# #### Define:
# Remove the rows where the dog names are beginning with lowercase as they are not real dog names.

# %% [markdown]
# #### Code

# %%
# Getting the list of names starting with lowercase using Regex
lower_names = twitter_archive.name.str.contains('^[a-z]', regex = True)
twitter_archive[lower_names].name.value_counts().sort_index()
# Out:
# a               55
# actually         2
# all              1
# an               7
# by               1
# getting          2
# his              1
# incredibly       1
# infuriating      1
# just             4
# life             1
# light            1
# mad              2
# my               1
# not              2
# officially       1
# old              1
# one              4
# quite            4
# space            1
# such             1
# the              8
# this             1
# unacceptable     1
# very             5
# Name: name, dtype: int64

# %%
# Getting rows where the names start with Uppercase only
twitter_archive_clean = twitter_archive_clean[twitter_archive_clean['name'].str.contains('^[A-Z]+')]

# %% [markdown]
# #### Test

# %%
twitter_archive_clean[lower_names].name.value_counts().sort_index()
# Out:
# Series([], Name: name, dtype: int64)

# %%
len(twitter_archive_clean[lower_names].name)
# Out:
# 0

# %% [markdown]
# ### Issue #5:

# %% [markdown]
# #### Define:
# Drop the rows where rating denominator is not 10, as this will not affect the analysis.

# %% [markdown]
# #### Code

# %%
# Getting the rows where the rating denominator is equal to 10
twitter_archive_clean = twitter_archive[twitter_archive['rating_denominator'] == 10]

# %% [markdown]
# #### Test

# %%
len(twitter_archive_clean.rating_denominator[twitter_archive.rating_denominator != 10])
# Out:
# 0

# %%
twitter_archive_clean.rating_denominator.value_counts()
# Out:
# 10    2333
# Name: rating_denominator, dtype: int64

# %% [markdown]
# There are no rows where the rating denominator is not equal to 10.

# %% [markdown]
# ### Issue #6:

# %% [markdown]
# #### Define:
# Convert timestamp and retweeted_status_timestamp columns to datetime in the twitter archive data.

# %% [markdown]
# #### Code

# %%
twitter_archive_clean['timestamp'] = pd.to_datetime(twitter_archive_clean['timestamp'])
twitter_archive_clean['retweeted_status_timestamp'] = pd.to_datetime(twitter_archive_clean['retweeted_status_timestamp'])

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2333 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2333 non-null   int64
#  1   in_reply_to_status_id       73 non-null     float64
#  2   in_reply_to_user_id         73 non-null     float64
#  3   timestamp                   2333 non-null   datetime64[ns, UTC]
#  4   source                      2333 non-null   object
#  5   text                        2333 non-null   object
#  6   retweeted_status_id         180 non-null    float64
#  7   retweeted_status_user_id    180 non-null    float64
#  8   retweeted_status_timestamp  180 non-null    datetime64[ns, UTC]
#  9   expanded_urls               2278 non-null   object
#  10  rating_numerator            2333 non-null   int64
#  11  rating_denominator          2333 non-null   int64
# ...

# %%
twitter_archive_clean.dtypes
# Out:
# tweet_id                                    int64
# in_reply_to_status_id                     float64
# in_reply_to_user_id                       float64
# timestamp                     datetime64[ns, UTC]
# source                                     object
# text                                       object
# retweeted_status_id                       float64
# retweeted_status_user_id                  float64
# retweeted_status_timestamp    datetime64[ns, UTC]
# expanded_urls                              object
# rating_numerator                            int64
# rating_denominator                          int64
# name                                       object
# doggo                                      object
# floofer                                    object
# pupper                                     object
# puppo                                      object
# dtype: object

# %% [markdown]
# It can be seen that the timestamp and retweeted_status_timestamp columns have been converted to datetime format.

# %% [markdown]
# ### Issue #7:

# %% [markdown]
# #### Define:
# Drop rows where retweeted_status_id is not null

# %% [markdown]
# #### Code

# %%
# Getting rows where retweets is null
twitter_archive_clean = twitter_archive_clean[twitter_archive_clean.retweeted_status_id.isnull()]

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.retweeted_status_id.notnull().sum()
# Out:
# 0

# %%
twitter_archive_clean.retweeted_status_user_id.notnull().sum()
# Out:
# 0

# %%
twitter_archive_clean.retweeted_status_timestamp.notnull().sum()
# Out:
# 0

# %% [markdown]
# ### Issue #8:

# %% [markdown]
# #### Define:
# Join the dog stages columns doggo, floofer, pupper, and puppo into a single column called dog_stage using lambda, and drop the columns.

# %% [markdown]
# #### Code

# %%
# Replace None in the dog stage columns with no space
twitter_archive_clean['doggo'].replace("None", "", inplace=True)
twitter_archive_clean['floofer'].replace("None", "", inplace=True)
twitter_archive_clean['pupper'].replace("None", "", inplace=True)
twitter_archive_clean['puppo'].replace("None", "", inplace=True)

# %%
# Joining the columns using lambda
twitter_archive_clean['dog_stage'] = twitter_archive_clean[['doggo', 'floofer', 'pupper', 'puppo']].apply(lambda x: ''.join(x), axis=1)

# %%
twitter_archive_clean.dog_stage.value_counts()
# Out:
#                 1809
# pupper           224
# doggo             75
# puppo             24
# doggopupper       10
# floofer            9
# doggopuppo         1
# doggofloofer       1
# Name: dog_stage, dtype: int64

# %% [markdown]
# There is the occurrence of more than one stage(doggopupper, doggopuppo, doggofloofer) and are also squeezed.

# %%
# Separating rows with a comma using mask function
twitter_archive_clean['dog_stage'].mask(twitter_archive_clean['dog_stage'] == 'doggopupper', 'doggo,pupper', inplace=True)
twitter_archive_clean['dog_stage'].mask(twitter_archive_clean['dog_stage'] == 'doggofloofer', 'doggo,floofer', inplace=True)
twitter_archive_clean['dog_stage'].mask(twitter_archive_clean['dog_stage'] == 'doggopuppo', 'doggo,puppo', inplace=True)

# %%
# Replacing empty spaces with None in the dog stage column
twitter_archive_clean['dog_stage'] = twitter_archive_clean['dog_stage'].replace('', 'None')

# %%
# Dropping columns
twitter_archive_clean.drop(['doggo', 'floofer', 'pupper', 'puppo', 'in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp', 'expanded_urls'], axis=1, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.dog_stage.value_counts()
# Out:
# None             1809
# pupper            224
# doggo              75
# puppo              24
# doggo,pupper       10
# floofer             9
# doggo,puppo         1
# doggo,floofer       1
# Name: dog_stage, dtype: int64

# %%
twitter_archive_clean.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'rating_numerator',
#        'rating_denominator', 'name', 'dog_stage'],
#       dtype='object')

# %% [markdown]
# ### Issue #9:

# %% [markdown]
# #### Define:
# Merging the three dataframes into a single dataframe.

# %% [markdown]
# #### Code

# %%
merged_data = twitter_archive_clean.merge(tweets_data_clean, how='inner', on='tweet_id')

# %%
merged_data2 = merged_data.merge(image_predictions_clean, how='inner', on='tweet_id')

# %% [markdown]
# #### Test

# %%
merged_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3936 entries, 0 to 3935
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            3936 non-null   int64
#  1   timestamp           3936 non-null   datetime64[ns, UTC]
#  2   source              3936 non-null   object
#  3   text                3936 non-null   object
#  4   rating_numerator    3936 non-null   int64
#  5   rating_denominator  3936 non-null   int64
#  6   name                3936 non-null   object
#  7   dog_stage           3936 non-null   object
#  8   retweet_count       3936 non-null   int64
#  9   favorite_count      3936 non-null   int64
#  10  jpg_url             3936 non-null   object
#  11  p1                  3936 non-null   object
#  12  p1_conf             3936 non-null   float64
#  13  p1_dog              3936 non-null   bool
#  14  p2                  3936 non-null   object
# ...

# %% [markdown]
# ### Issue #10

# %% [markdown]
# #### Define:
# Convert tweet_id to string, dog_stage, p1_dog, p2_dog, p3_dog to categorical datatypes.

# %% [markdown]
# #### Code

# %%
merged_data2.tweet_id = merged_data2.tweet_id.astype(str)
merged_data2.dog_stage = merged_data2.dog_stage.astype('category')
merged_data2.p1_dog = merged_data2.p1_dog.astype('category')
merged_data2.p2_dog = merged_data2.p2_dog.astype('category')
merged_data2.p3_dog = merged_data2.p3_dog.astype('category')

# %%
merged_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3936 entries, 0 to 3935
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            3936 non-null   object
#  1   timestamp           3936 non-null   datetime64[ns, UTC]
#  2   source              3936 non-null   object
#  3   text                3936 non-null   object
#  4   rating_numerator    3936 non-null   int64
#  5   rating_denominator  3936 non-null   int64
#  6   name                3936 non-null   object
#  7   dog_stage           3936 non-null   category
#  8   retweet_count       3936 non-null   int64
#  9   favorite_count      3936 non-null   int64
#  10  jpg_url             3936 non-null   object
#  11  p1                  3936 non-null   object
#  12  p1_conf             3936 non-null   float64
#  13  p1_dog              3936 non-null   category
#  14  p2                  3936 non-null   object
# ...

# %% [markdown]
# Drop the text column also:

# %%
merged_data2.drop(['text'], axis=1, inplace=True)

# %%
merged_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3936 entries, 0 to 3935
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            3936 non-null   object
#  1   timestamp           3936 non-null   datetime64[ns, UTC]
#  2   source              3936 non-null   object
#  3   rating_numerator    3936 non-null   int64
#  4   rating_denominator  3936 non-null   int64
#  5   name                3936 non-null   object
#  6   dog_stage           3936 non-null   category
#  7   retweet_count       3936 non-null   int64
#  8   favorite_count      3936 non-null   int64
#  9   jpg_url             3936 non-null   object
#  10  p1                  3936 non-null   object
#  11  p1_conf             3936 non-null   float64
#  12  p1_dog              3936 non-null   category
#  13  p2                  3936 non-null   object
#  14  p2_conf             3936 non-null   float64
# ...

# %% [markdown]
# #### Additional Cleaning

# %% [markdown]
# It was discovered in the source column that the text has not been extracted from the url for easy analysis

# %%
merged_data2.source.value_counts()
# Out:
# Twitter for iPhone                                                                     3860
# Twitter Web Client                                                                       56
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      20
# Name: source, dtype: int64

# %%
merged_data2.replace('<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'TweetDeck', inplace=True)

# %%
merged_data2.source.value_counts()
# Out:
# Twitter for iPhone    3860
# Twitter Web Client      56
# TweetDeck               20
# Name: source, dtype: int64

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
# Storing into a csv master dataset
merged_data2.to_csv("twitter_archive_master.csv", index=False)

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
# Reading the master data into a dataframe
twitter_archive_master = pd.read_csv('twitter_archive_master.csv')

# %%
twitter_archive_master.head(3)
# Out:
#              tweet_id                  timestamp              source  \
# 0  892420643555336193  2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1  892420643555336193  2017-08-01 16:23:56+00:00  Twitter for iPhone
# 2  892177421306343426  2017-08-01 00:17:27+00:00  Twitter for iPhone
#
#    rating_numerator  rating_denominator     name dog_stage  retweet_count  \
# 0                13                  10  Phineas      None           6978
# 1                13                  10  Phineas      None           6978
# 2                13                  10    Tilly      None           5279
#
#    favorite_count                                          jpg_url         p1  \
# 0           33722  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg     orange
# 1           33722  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg     orange
# 2           29250  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg  Chihuahua
#
# ...

# %% [markdown]
# ### Question 1: Which Dog stage has the most likes?

# %%
twitter_archive_master.groupby('dog_stage')['favorite_count'].mean().sort_values(ascending=False)
# Out:
# dog_stage
# doggo,puppo      41835.000000
# puppo            19518.363636
# doggo            17547.403226
# doggo,floofer    14816.000000
# doggo,pupper     12005.888889
# floofer          11188.428571
# None              7293.989778
# pupper            6186.216749
# Name: favorite_count, dtype: float64

# %% [markdown]
# Here, it can be seen that the dog stages that got the most likes is the doggo,puppo with 41835 likes, followed by the puppo and the doggo dog stage.

# %% [markdown]
# ### Question 2: Which Dog stage has the most retweets?

# %%
twitter_archive_master.groupby('dog_stage')['retweet_count'].mean().sort_values(ascending=False)
# Out:
# dog_stage
# doggo,puppo      16089.000000
# doggo             5950.096774
# puppo             5307.090909
# floofer           3963.714286
# doggo,pupper      3441.555556
# doggo,floofer     2786.000000
# None              2071.469032
# pupper            1901.438424
# Name: retweet_count, dtype: float64

# %% [markdown]
# It can be seen that the dog stage that got the most retweets is the doggo,puppo dog stage, followed by the doggo dog stage and then the puppo dog stage.

# %% [markdown]
# ### Insights:
# 1. The dog stage with the most likes is the doggo,puppo dog stage.
#
# 2. The dog stage with the most retweets is the doggo,puppo dog stage.
#
# 3. There is a strong positive correlation between retweet_count and favorite_count.
#
# 4. The majority of the tweets made by @WeRateDogs were from an iPhone.

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### Question 3: Is there a relationship between favorite_count(likes) and retweet_count(retweets)?

# %%
twitter_archive_master.plot(x = "retweet_count", y = "favorite_count", kind ='scatter', figsize=(10,6))
plt.title('Relationship between Retweets and Likes', fontsize=18)
plt.xlabel('Retweets', fontsize=14)
plt.ylabel('Likes', fontsize=14);

# %%
from scipy.stats import pearsonr

# %%
pearsonr(twitter_archive_master.retweet_count, twitter_archive_master.favorite_count)
# Out:
# (0.9280730972537378, 0.0)

# %% [markdown]
# Since r=0.92, which is close to 1, we can say that there is a strong correlation between retweets and likes, as tweets that gather more retweets are likely to gather more likes.

# %% [markdown]
# It can be seen here that there is a strong positive relationship/correlation between retweet_count and favorite_count, as the amount of likes increases, the amount of retweets increases also.

# %% [markdown]
# ### Question 4: How is the source of tweet shared?

# %%
twitter_archive_master.source.value_counts()
# Out:
# Twitter for iPhone    3860
# Twitter Web Client      56
# TweetDeck               20
# Name: source, dtype: int64

# %%
twitter_archive_master['source'].value_counts().plot(kind='bar', figsize=(8,8))
plt.title('Tweet Sources', fontsize=18)
plt.ylabel('Count', fontsize=15)
plt.xlabel('Sources', fontsize=15);

# %% [markdown]
# The bar chart shows that majority of the tweets made by @WeRateDogs were tweeted from an iPhone.

# %%
twitter_archive_master.groupby('dog_stage')['favorite_count'].mean().sort_values(ascending=False)
# Out:
# dog_stage
# doggo,puppo      41835.000000
# puppo            19518.363636
# doggo            17547.403226
# doggo,floofer    14816.000000
# doggo,pupper     12005.888889
# floofer          11188.428571
# None              7293.989778
# pupper            6186.216749
# Name: favorite_count, dtype: float64

# %%
twitter_archive_master.groupby('dog_stage')['favorite_count'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(10,6))
plt.title('Dog Stage Likes', fontsize=18)
plt.ylabel('Favourite Count', fontsize=14)
plt.xlabel('Dog Stage', fontsize=14);

# %% [markdown]
# The bar chart above shows that the doggo,puppo dog stage got the most likes compared to other dog stages by far.
